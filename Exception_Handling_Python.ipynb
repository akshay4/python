# %% [markdown]
# # Exception Handling in Python

# %%
#all errors are generated by the shell when running the program are exceptions

# %%
#example
try :
    x = int(input("Enter an number :" ))
    y = 1/0
except :
    print("error!! it should be an integer value")
# Out:
# Enter an number :123456
# error!! it should be an integer value

# %%
try :
    x = int(input("Enter number :"))/int(input("Enter a value :"))
    f = open(input("Enter file name: "))
    f.close()
except Exception as error :
    print("Error !!",error)
else :
    print("Do not poke me boi")
finally :
    print("Thanx for using this program")
# Out:
# Enter number :546
# Enter a value :125
# Enter file name: lol
# Error !! [Errno 2] No such file or directory: 'lol'
# Thanx for using this program
